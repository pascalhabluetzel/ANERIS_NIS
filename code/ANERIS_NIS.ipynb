# %%
import re
import time
import math
import urllib.parse
import requests
from tqdm import tqdm  # status bars
import pandas as pd

# --------------------------------------------------------
# USER INPUT: file paths & parameters
# --------------------------------------------------------
LOCATIONS_FILE = "locations.tsv"  # your uploaded locations file
SPECIES_FILE = "species.tsv"      # your uploaded species file
OUTPUT_FILE = "analysis_results.tsv"

MAX_OBIS_RECORDS = 10000          # how many OBIS occurrences to consider
MAX_REGION_DIAGONAL_KM = 3000    # filter out marine regions larger than this


# --------------------------------------------------------
# CONSTANTS
# --------------------------------------------------------
BASE_OBIS = "https://api.obis.org/v3"
BASE_MARINE_REGIONS = "https://www.marineregions.org/rest"
BASE_WORMS = "https://www.marinespecies.org/rest"


# ========================================================
# 0. Small helpers
# ========================================================
def dms_to_decimal(dms_str):
    """
    Convert a coordinate in DMS format like '51°06'39.3"N'
    or '2°36'13.6"E' to decimal degrees.
    """
    if not isinstance(dms_str, str):
        raise ValueError(f"Invalid DMS value: {dms_str}")

    # matches: degrees, minutes, seconds, hemisphere (N/S/E/W)
    m = re.match(
        r"^\s*(\d+)[°:\s]+(\d+)[\'’:\s]+(\d+(?:\.\d+)?)[\"”]?\s*([NSEW])\s*$",
        dms_str.strip()
    )
    if not m:
        raise ValueError(f"Cannot parse DMS: {dms_str}")

    deg, mins, secs, hemi = m.groups()
    deg = float(deg)
    mins = float(mins)
    secs = float(secs)

    decimal = deg + mins / 60.0 + secs / 3600.0
    if hemi in ("S", "W"):
        decimal = -decimal
    return decimal


# ========================================================
# 1. OBIS helpers: occurrences + sea-only distance
# ========================================================
def get_obis_occurrences(scientific_name, limit=1000):
    """
    Retrieve occurrence coordinates for a given species from OBIS.
    Returns a list of dicts with:
      - decimalLatitude
      - decimalLongitude
      - occurrenceID (OBIS occurrence id, if present)
    """
    url = f"{BASE_OBIS}/occurrence"
    params = {
        "scientificname": scientific_name,
        "size": limit
    }
    r = requests.get(url, params=params, timeout=60)
    r.raise_for_status()
    data = r.json()

    records = []
    for rec in data.get("results", []):
        lat = rec.get("decimalLatitude")
        lon = rec.get("decimalLongitude")
        if lat is None or lon is None:
            continue
        records.append({
            "decimalLatitude": float(lat),
            "decimalLongitude": float(lon),
            "occurrenceID": rec.get("id")
        })
    return records


def sea_distance_km(ref_lat, ref_lon, lat, lon):
    """
    Shortest sea route distance in km using searoute.

    Requires:
      pip install searoute
    """
    import searoute as sr  # imported here to avoid dependency if not needed

    origin = [ref_lon, ref_lat]     # searoute expects [lon, lat]
    destination = [lon, lat]

    route = sr.searoute(origin, destination, units="km")
    if route is None:
        return None
    return float(route.properties["length"])


def find_closest_obis_occurrence(scientific_name, new_lat, new_lon, limit=200):
    """
    From all OBIS occurrences of 'scientific_name', find the one with
    the shortest sea-only distance to (new_lat, new_lon).
    Shows a tqdm progress bar for the sea-routing.
    """
    occurrences = get_obis_occurrences(scientific_name, limit=limit)
    if not occurrences:
        raise RuntimeError(
            f"No OBIS occurrences with coordinates found for '{scientific_name}'."
        )

    best = None

    # Progress bar over all OBIS records
    for rec in tqdm(occurrences,
                    desc=f"Sea-routing OBIS for {scientific_name}",
                    unit="record",
                    leave=False):
        lat = rec["decimalLatitude"]
        lon = rec["decimalLongitude"]
        try:
            d = sea_distance_km(new_lat, new_lon, lat, lon)
        except Exception as e:
            print(f"[WARN] sea routing failed for ({lat}, {lon}): {e}")
            d = None

        rec["sea_distance_km"] = d
        if d is None:
            continue

        if best is None or d < best["sea_distance_km"]:
            best = rec

    if best is None:
        raise RuntimeError(
            f"No valid sea-only distances could be computed to OBIS occurrences "
            f"for '{scientific_name}'."
        )

    return best


# ========================================================
# 2. Marine Regions helpers (with bbox size filter)
# ========================================================

# cache for MRGID -> diagonal distance (km)
_region_diag_cache = {}


def bbox_diagonal_km_from_degrees(min_lat, min_lon, max_lat, max_lon):
    """
    Approximate diagonal distance (km) of a lat/lon bounding box
    using simple degree-to-km conversions.
    """
    if not (-90 <= min_lat <= 90 and -90 <= max_lat <= 90):
        return None
    if not (-180 <= min_lon <= 180 and -180 <= max_lon <= 180):
        return None

    dlat_deg = max_lat - min_lat
    dlon_deg = max_lon - min_lon

    # Normalize longitude difference to [-180, 180]
    if dlon_deg > 180:
        dlon_deg -= 360
    elif dlon_deg < -180:
        dlon_deg += 360

    lat_km_per_deg = 111.32
    mid_lat = (min_lat + max_lat) / 2.0
    lon_km_per_deg = 111.32 * math.cos(math.radians(mid_lat))

    dlat_km = dlat_deg * lat_km_per_deg
    dlon_km = dlon_deg * lon_km_per_deg

    diag_km = math.sqrt(dlat_km**2 + dlon_km**2)

    if diag_km > 25000:
        return None

    return diag_km


def get_region_bbox_diagonal_km(mrgid):
    """
    Get approximate diagonal (km) of the bounding box for a Marine Region (MRGID).
    Uses a small cache to avoid repeated calls for the same MRGID.
    """
    mrgid_str = str(mrgid)
    if mrgid_str in _region_diag_cache:
        return _region_diag_cache[mrgid_str]

    url = f"{BASE_MARINE_REGIONS}/getGazetteerRecordByMRGID.json/{mrgid_str}/"

    try:
        resp = requests.get(url, headers={"accept": "application/json"}, timeout=15)
        resp.raise_for_status()
    except requests.RequestException as e:
        print(f"[WARN] Request error for MRGID {mrgid_str}: {e}")
        _region_diag_cache[mrgid_str] = None
        return None

    try:
        data = resp.json()
    except ValueError:
        print(f"[WARN] Could not decode JSON for MRGID {mrgid_str}")
        _region_diag_cache[mrgid_str] = None
        return None

    # API may return a list or a dict
    if isinstance(data, list):
        if not data:
            _region_diag_cache[mrgid_str] = None
            return None
        data = data[0]

    if not isinstance(data, dict):
        _region_diag_cache[mrgid_str] = None
        return None

    min_lat = data.get("minLatitude")
    min_lon = data.get("minLongitude")
    max_lat = data.get("maxLatitude")
    max_lon = data.get("maxLongitude")

    if None in (min_lat, min_lon, max_lat, max_lon):
        _region_diag_cache[mrgid_str] = None
        return None

    try:
        min_lat = float(min_lat)
        min_lon = float(min_lon)
        max_lat = float(max_lat)
        max_lon = float(max_lon)
    except ValueError:
        _region_diag_cache[mrgid_str] = None
        return None

    diag_km = bbox_diagonal_km_from_degrees(min_lat, min_lon, max_lat, max_lon)
    _region_diag_cache[mrgid_str] = diag_km
    return diag_km


def get_filtered_mrgids_for_coord(lat_dd, lon_dd, max_diagonal_km=3000):
    """
    Get Marine Regions MRGIDs for a point and filter out regions whose bounding
    box diagonal is more than max_diagonal_km.

    Returns a list of MRGID strings that:
      - have bounding box info, AND
      - diagonal distance <= max_diagonal_km
    """
    try:
        lat = float(lat_dd)
        lon = float(lon_dd)
    except (TypeError, ValueError):
        return []

    url = f"{BASE_MARINE_REGIONS}/getGazetteerRecordsByLatLong.json/{lat}/{lon}/"

    try:
        resp = requests.get(url, headers={"accept": "application/json"}, timeout=15)
        resp.raise_for_status()
        regions = resp.json()
    except Exception as e:
        print(f"[WARN] Marine Regions request failed for {lat}, {lon}: {e}")
        return []

    if not regions or not isinstance(regions, list):
        return []

    filtered_mrgids = []

    for item in regions:
        mrgid = item.get("MRGID")
        if not mrgid:
            continue

        diag_km = get_region_bbox_diagonal_km(mrgid)

        # Keep only if bbox is known AND size <= threshold
        if diag_km is not None and diag_km <= max_diagonal_km:
            filtered_mrgids.append(str(mrgid))

    return filtered_mrgids


# ========================================================
# 3. WoRMS/WRiMS helpers
# ========================================================

aphia_cache = {}
dist_cache = {}


def get_aphia_id(scientific_name, marine_only=True):
    """
    Use WoRMS REST:
      GET /AphiaIDByName/{ScientificName}?marine_only=true

    Returns AphiaID (int) or None
    """
    if scientific_name in aphia_cache:
        return aphia_cache[scientific_name]

    encoded_name = urllib.parse.quote(scientific_name)
    url = f"{BASE_WORMS}/AphiaIDByName/{encoded_name}"

    params = {}
    if marine_only:
        params["marine_only"] = "true"

    try:
        r = requests.get(url, params=params, timeout=20)
        if r.status_code == 204 or not r.text.strip():
            aphia_cache[scientific_name] = None
            return None
        r.raise_for_status()
        text = r.text.strip()
        if text == "0":
            aphia_cache[scientific_name] = None
            return None
        aphia_id = int(text)
    except Exception as e:
        print(f"[WARN] Could not get AphiaID for '{scientific_name}': {e}")
        aphia_cache[scientific_name] = None
        return None

    aphia_cache[scientific_name] = aphia_id
    time.sleep(0.1)
    return aphia_id


def get_distributions_for_aphia(aphia_id):
    """
    Use WoRMS REST:
      GET /AphiaDistributionsByAphiaID/{ID}

    Returns a list of dicts.
    """
    if aphia_id in dist_cache:
        return dist_cache[aphia_id]

    url = f"{BASE_WORMS}/AphiaDistributionsByAphiaID/{aphia_id}"

    try:
        r = requests.get(url, timeout=20)
        if r.status_code == 204 or not r.text.strip():
            dist_cache[aphia_id] = []
            return []
        r.raise_for_status()
        data = r.json()
        if not isinstance(data, list):
            data = []
    except Exception as e:
        print(f"[WARN] Could not get distributions for AphiaID {aphia_id}: {e}")
        dist_cache[aphia_id] = []
        return []

    dist_cache[aphia_id] = data
    time.sleep(0.1)
    return data


def extract_mrgid_from_locationID(locationID):
    """
    distribution['locationID'] looks like:
      'http://marineregions.org/mrgid/7130'
    We want the numeric MRGID as string, e.g. '7130'.
    """
    if not isinstance(locationID, str):
        return None
    m = re.search(r"/mrgid/(\d+)", locationID)
    return m.group(1) if m else None


def classify_invasiveness(scientific_name, mrgids_for_location):
    """
    Returns dict with:
      wrims_has_record, wrims_invasive, wrims_establishment, wrims_matching_mrgid
    """
    if not mrgids_for_location:
        return {
            "wrims_has_record": False,
            "wrims_invasive": None,
            "wrims_establishment": None,
            "wrims_matching_mrgid": None
        }

    aphia_id = get_aphia_id(scientific_name)
    if aphia_id is None:
        return {
            "wrims_has_record": False,
            "wrims_invasive": None,
            "wrims_establishment": None,
            "wrims_matching_mrgid": None
        }

    distribs = get_distributions_for_aphia(aphia_id)
    if not distribs:
        return {
            "wrims_has_record": False,
            "wrims_invasive": None,
            "wrims_establishment": None,
            "wrims_matching_mrgid": None
        }

    # Build index: MRGID -> list of distribution entries
    mrgid_to_records = {}
    for d in distribs:
        loc_id = d.get("locationID")
        mrgid = extract_mrgid_from_locationID(loc_id)
        if not mrgid:
            continue
        mrgid_to_records.setdefault(mrgid, []).append(d)

    # Check if any of the location's MRGIDs appears in the distribution records
    for loc_mrgid in mrgids_for_location:
        recs = mrgid_to_records.get(loc_mrgid)
        if not recs:
            continue

        best_invasive = None
        best_establishment = None

        for d in recs:
            invasiveness = (d.get("invasiveness") or "").lower()
            establishment = (d.get("establishmentMeans") or "").lower()

            if "invasive" in invasiveness:
                best_invasive = "invasive"
                best_establishment = establishment or None
                break

            if any(word in establishment for word in
                   ["introduced", "alien", "non-indigenous", "nonindigenous"]):
                best_invasive = "introduced"
                best_establishment = establishment or "introduced"

        if best_invasive is not None:
            return {
                "wrims_has_record": True,
                "wrims_invasive": best_invasive,
                "wrims_establishment": best_establishment,
                "wrims_matching_mrgid": loc_mrgid,
            }

    # there are distributions, but nothing matching those MRGIDs with invasiveness info
    return {
        "wrims_has_record": True,
        "wrims_invasive": None,
        "wrims_establishment": None,
        "wrims_matching_mrgid": None
    }


def wrims_label(status_dict):
    """
    Human-friendly label.
    """
    if not status_dict["wrims_has_record"]:
        return "no WRiMS distribution record"

    inv = status_dict["wrims_invasive"]
    if inv == "invasive":
        return "probably invasive"
    if inv == "introduced":
        return "probably introduced"

    return "unknown status (possibly native)"


def classify_with_progress(scientific_name, locations):
    """
    Run WRiMS classification for each (lat, lon) in `locations`
    with a tqdm progress bar.

    locations: dict[label] = (lat, lon)

    Returns dict[label] = {
        "mrgids": [...],
        "status": {...},
        "label": "human-friendly label"
    }
    """
    results = {}

    for key in tqdm(locations.keys(),
                    desc=f"WRiMS status for {scientific_name}",
                    unit="location",
                    leave=False):
        lat, lon = locations[key]
        mrgids = get_filtered_mrgids_for_coord(
            lat, lon, max_diagonal_km=MAX_REGION_DIAGONAL_KM
        )
        status = classify_invasiveness(scientific_name, mrgids)
        results[key] = {
            "mrgids": mrgids,
            "status": status,
            "label": wrims_label(status)
        }

    return results


# ========================================================
# 4. MAIN FLOW: batch over TSV files
# ========================================================
def main():
    # 4.1 Read input TSVs
    print(f"Reading locations from {LOCATIONS_FILE}")
    locations = pd.read_csv(LOCATIONS_FILE, sep="\t")

    print(f"Reading species from {SPECIES_FILE}")
    species = pd.read_csv(SPECIES_FILE, sep="\t")

    # 4.2 Convert DMS to decimal degrees
    print("Converting coordinates to decimal degrees...")
    locations["decimalLatitude"] = locations["verbatimLatitude"].apply(dms_to_decimal)
    locations["decimalLongitude"] = locations["verbatimLongitude"].apply(dms_to_decimal)

    # 4.3 Join species with locations via locationID
    merged = species.merge(locations, on="locationID", how="inner")

    print(f"Total (location, species) cases to analyse: {len(merged)}")

    results = []

    # 4.4 Loop over each row and run your full analysis
    for _, row in tqdm(merged.iterrows(),
                       total=len(merged),
                       desc="Total analyses",
                       unit="case"):
        loc_id = row["locationID"]
        verb_lat = row["verbatimLatitude"]
        verb_lon = row["verbatimLongitude"]
        lat = float(row["decimalLatitude"])
        lon = float(row["decimalLongitude"])
        sci_name = row["scientificName"]
        taxon_rank = row.get("taxonRank", "")

        # ---- OBIS: closest occurrence by sea-only distance ----
        try:
            closest = find_closest_obis_occurrence(
                sci_name,
                lat,
                lon,
                limit=MAX_OBIS_RECORDS
            )
            obis_lat = closest["decimalLatitude"]
            obis_lon = closest["decimalLongitude"]
            obis_dist_km = closest["sea_distance_km"]
        except Exception as e:
            print(f"[WARN] OBIS step failed for {sci_name} at {loc_id}: {e}")
            closest = None
            obis_lat = None
            obis_lon = None
            obis_dist_km = None

        # ---- WRiMS classification for new & closest OBIS locations ----
        locations_dict = {
            "new_observation": (lat, lon)
        }
        if closest is not None:
            locations_dict["closest_obis"] = (obis_lat, obis_lon)

        wrims_results = classify_with_progress(sci_name, locations_dict)

        new_label = wrims_results["new_observation"]["label"]
        obis_label = wrims_results.get("closest_obis", {}).get("label")

        # ---- Collect row for output ----
        results.append({
            "locationID": loc_id,
            "verbatimLatitude": verb_lat,
            "verbatimLongitude": verb_lon,
            "decimalLatitude": lat,
            "decimalLongitude": lon,
            "scientificName": sci_name,
            "taxonRank": taxon_rank,
            "closest_obis_lat": obis_lat,
            "closest_obis_lon": obis_lon,
            "distance_over_water_km": obis_dist_km,
            "wrims_status_new_location": new_label,
            "wrims_status_closest_obis": obis_label,
        })

    # 4.5 Write single TSV output
    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_FILE, sep="\t", index=False)
    print(f"\nDone. Results written to: {OUTPUT_FILE}")


if __name__ == "__main__":
    main()
# Out:
# Reading locations from locations.tsv
# Reading species from species.tsv
# Converting coordinates to decimal degrees...
# Total (location, species) cases to analyse: 50
# Total analyses:   0%|                                    | 0/50 [00:00<?, ?case/s]
# Sea-routing OBIS for Acartia tonsa:   0%|           | 0/10000 [00:00<?, ?record/s]
# Sea-routing OBIS for Acartia tonsa:   0%| | 50/10000 [00:00<00:20, 493.86record/s]
# Sea-routing OBIS for Acartia tonsa:   1%| | 106/10000 [00:00<00:18, 527.07record/s
# Sea-routing OBIS for Acartia tonsa:   2%| | 163/10000 [00:00<00:18, 540.13record/s
# Sea-routing OBIS for Acartia tonsa:   2%| | 218/10000 [00:00<00:18, 517.93record/s
# Sea-routing OBIS for Acartia tonsa:   3%| | 284/10000 [00:00<00:17, 555.15record/s
# Sea-routing OBIS for Acartia tonsa:   4%| | 360/10000 [00:00<00:15, 611.93record/s
# Sea-routing OBIS for Acartia tonsa:  23%|▏| 2347/10000 [00:04<00:14, 529.59record/
# Sea-routing OBIS for Acartia tonsa:  24%|▏| 2402/10000 [00:04<00:14, 523.77record/
# Sea-routing OBIS for Acartia tonsa:  25%|▏| 2456/10000 [00:04<00:14, 526.66record/
# Sea-routing OBIS for Acartia tonsa:  25%|▎| 2510/10000 [00:04<00:14, 526.09record/
# Sea-routing OBIS for Acartia tonsa:  26%|▎| 2566/10000 [00:04<00:13, 534.00record/
# Sea-routing OBIS for Acartia tonsa:  26%|▎| 2633/10000 [00:04<00:12, 569.68record/
# Sea-routing OBIS for Acartia tonsa:  27%|▎| 2691/10000 [00:04<00:13, 559.42record/
# Sea-routing OBIS for Acartia tonsa:  27%|▎| 2748/10000 [00:05<00:13, 550.08record/
# Sea-routing OBIS for Acartia tonsa:  28%|▎| 2804/10000 [00:05<00:13, 524.35record/
# Sea-routing OBIS for Acartia tonsa:  29%|▎| 2879/10000 [00:05<00:12, 582.99record/
# Sea-routing OBIS for Acartia tonsa:  29%|▎| 2938/10000 [00:05<00:12, 578.67record/
# Sea-routing OBIS for Acartia tonsa:  30%|▎| 3004/10000 [00:05<00:11, 599.06record/
# Sea-routing OBIS for Acartia tonsa:  31%|▎| 3065/10000 [00:05<00:11, 586.03record/
# Sea-routing OBIS for Acartia tonsa:  31%|▎| 3124/10000 [00:05<00:12, 572.77record/
# Sea-routing OBIS for Acartia tonsa:  32%|▎| 3183/10000 [00:05<00:12, 566.52record/
# Sea-routing OBIS for Acartia tonsa:  32%|▎| 3242/10000 [00:05<00:11, 566.12record/
# Sea-routing OBIS for Acartia tonsa:  33%|▎| 3299/10000 [00:05<00:12, 555.23record/
# Sea-routing OBIS for Acartia tonsa:  34%|▎| 3358/10000 [00:06<00:11, 562.89record/
# Sea-routing OBIS for Acartia tonsa:  34%|▎| 3417/10000 [00:06<00:11, 567.96record/
# Sea-routing OBIS for Acartia tonsa:  35%|▎| 3476/10000 [00:06<00:11, 566.82record/
# Sea-routing OBIS for Acartia tonsa:  36%|▎| 3552/10000 [00:06<00:10, 618.24record/
# Sea-routing OBIS for Acartia tonsa:  36%|▎| 3617/10000 [00:06<00:10, 613.63record/
# Sea-routing OBIS for Acartia tonsa:  37%|▎| 3679/10000 [00:06<00:10, 578.67record/
# Sea-routing OBIS for Acartia tonsa:  37%|▎| 3738/10000 [00:06<00:10, 577.29record/
# Sea-routing OBIS for Acartia tonsa:  38%|▍| 3796/10000 [00:06<00:10, 576.44record/
# Sea-routing OBIS for Acartia tonsa:  39%|▍| 3854/10000 [00:06<00:11, 522.83record/
# Sea-routing OBIS for Acartia tonsa:  39%|▍| 3908/10000 [00:07<00:12, 495.99record/
# Sea-routing OBIS for Acartia tonsa:  40%|▍| 3985/10000 [00:07<00:10, 563.94record/
# Sea-routing OBIS for Acartia tonsa:  40%|▍| 4043/10000 [00:07<00:10, 543.13record/
# Sea-routing OBIS for Acartia tonsa:  41%|▍| 4105/10000 [00:07<00:10, 560.76record/
# Sea-routing OBIS for Acartia tonsa:  78%|▊| 7752/10000 [00:14<00:04, 545.92record/
# Sea-routing OBIS for Acartia tonsa:  78%|▊| 7816/10000 [00:14<00:03, 568.43record/
# Sea-routing OBIS for Acartia tonsa:  79%|▊| 7883/10000 [00:14<00:03, 591.78record/
# Sea-routing OBIS for Acartia tonsa:  80%|▊| 7951/10000 [00:14<00:03, 610.43record/
# Sea-routing OBIS for Acartia tonsa:  80%|▊| 8013/10000 [00:14<00:03, 579.02record/
# Sea-routing OBIS for Acartia tonsa:  81%|▊| 8072/10000 [00:14<00:03, 558.01record/
# Sea-routing OBIS for Acartia tonsa:  81%|▊| 8133/10000 [00:14<00:03, 567.97record/
# Sea-routing OBIS for Acartia tonsa:  82%|▊| 8200/10000 [00:14<00:03, 592.11record/
# Sea-routing OBIS for Acartia tonsa:  83%|▊| 8260/10000 [00:15<00:03, 571.05record/
# Sea-routing OBIS for Acartia tonsa:  83%|▊| 8318/10000 [00:15<00:03, 553.57record/
# Sea-routing OBIS for Acartia tonsa:  84%|▊| 8374/10000 [00:15<00:03, 530.18record/
# Sea-routing OBIS for Acartia tonsa:  84%|▊| 8433/10000 [00:15<00:02, 541.41record/
# Sea-routing OBIS for Acartia tonsa:  85%|▊| 8488/10000 [00:15<00:02, 537.29record/
# Sea-routing OBIS for Acartia tonsa:  85%|▊| 8547/10000 [00:15<00:02, 546.47record/
# Sea-routing OBIS for Acartia tonsa:  86%|▊| 8602/10000 [00:15<00:02, 544.58record/
# Sea-routing OBIS for Acartia tonsa:  87%|▊| 8657/10000 [00:15<00:02, 544.89record/
# Sea-routing OBIS for Acartia tonsa:  87%|▊| 8716/10000 [00:15<00:02, 550.38record/
# Sea-routing OBIS for Acartia tonsa:  88%|▉| 8781/10000 [00:15<00:02, 575.65record/
# Sea-routing OBIS for Acartia tonsa:  89%|▉| 8857/10000 [00:16<00:01, 628.65record/
# Sea-routing OBIS for Acartia tonsa:  89%|▉| 8921/10000 [00:16<00:01, 599.89record/
# Sea-routing OBIS for Acartia tonsa:  90%|▉| 8982/10000 [00:16<00:01, 557.73record/
# Sea-routing OBIS for Acartia tonsa:  90%|▉| 9039/10000 [00:16<00:01, 552.35record/
# Sea-routing OBIS for Acartia tonsa:  91%|▉| 9100/10000 [00:16<00:01, 556.35record/
# Sea-routing OBIS for Acartia tonsa:  92%|▉| 9164/10000 [00:16<00:01, 578.86record/
# Sea-routing OBIS for Acartia tonsa:  92%|▉| 9223/10000 [00:16<00:01, 576.95record/
# Sea-routing OBIS for Acartia tonsa:  93%|▉| 9281/10000 [00:16<00:01, 564.19record/
# Sea-routing OBIS for Acartia tonsa:  94%|▉| 9358/10000 [00:16<00:01, 621.83record/
# Sea-routing OBIS for Acartia tonsa:  94%|▉| 9421/10000 [00:17<00:00, 610.70record/
# Sea-routing OBIS for Acartia tonsa:  95%|▉| 9485/10000 [00:17<00:00, 612.19record/
# Sea-routing OBIS for Acartia tonsa:  96%|▉| 9561/10000 [00:17<00:00, 654.04record/
# Sea-routing OBIS for Acartia tonsa:  96%|▉| 9627/10000 [00:17<00:00, 608.38record/
# Sea-routing OBIS for Acartia tonsa:  97%|▉| 9689/10000 [00:17<00:00, 596.04record/
# Sea-routing OBIS for Acartia tonsa:  98%|▉| 9750/10000 [00:17<00:00, 570.85record/
# Sea-routing OBIS for Acartia tonsa:  98%|▉| 9814/10000 [00:17<00:00, 589.23record/
# Sea-routing OBIS for Acartia tonsa:  99%|▉| 9874/10000 [00:17<00:00, 552.03record/
# Sea-routing OBIS for Acartia tonsa:  99%|▉| 9936/10000 [00:17<00:00, 557.46record/
#
# WRiMS status for Acartia tonsa:   0%|                 | 0/2 [00:00<?, ?location/s]
# WRiMS status for Acartia tonsa:  50%|████▌    | 1/2 [00:15<00:15, 15.73s/location]
# WRiMS status for Acartia tonsa: 100%|█████████| 2/2 [00:18<00:00,  8.26s/location]
# Total analyses:   2%|▌                           | 1/50 [00:59<48:11, 59.02s/case]
# Sea-routing OBIS for Ammothea hilgendorfi:   0%|      | 0/250 [00:00<?, ?record/s]
# Sea-routing OBIS for Ammothea hilgendorfi:   6%| | 14/250 [00:00<00:01, 133.52reco
# Sea-routing OBIS for Ammothea hilgendorfi:  14%|▏| 35/250 [00:00<00:01, 170.67reco
# Sea-routing OBIS for Ammothea hilgendorfi:  22%|▏| 55/250 [00:00<00:01, 181.16reco
# Sea-routing OBIS for Ammothea hilgendorfi:  32%|▎| 81/250 [00:00<00:00, 208.29reco
# Sea-routing OBIS for Ammothea hilgendorfi:  41%|▍| 102/250 [00:00<00:00, 203.79rec
# Sea-routing OBIS for Ammothea hilgendorfi:  50%|▍| 124/250 [00:00<00:00, 206.45rec
# Sea-routing OBIS for Ammothea hilgendorfi:  60%|▌| 151/250 [00:00<00:00, 222.34rec
# Sea-routing OBIS for Ammothea hilgendorfi:  71%|▋| 177/250 [00:00<00:00, 229.83rec
# Sea-routing OBIS for Ammothea hilgendorfi:  81%|▊| 203/250 [00:00<00:00, 235.72rec
# Sea-routing OBIS for Ammothea hilgendorfi:  91%|▉| 227/250 [00:01<00:00, 228.91rec
# Sea-routing OBIS for Ammothea hilgendorfi: 100%|█| 250/250 [00:01<00:00, 201.05rec
#
# WRiMS status for Ammothea hilgendorfi:   0%|          | 0/2 [00:00<?, ?location/s]
# WRiMS status for Ammothea hilgendorfi:  50%|█ | 1/2 [00:02<00:02,  2.66s/location]
# WRiMS status for Ammothea hilgendorfi: 100%|██| 2/2 [00:08<00:00,  4.47s/location]
# Total analyses:   4%|█                           | 2/50 [01:09<24:29, 30.61s/case]
# Sea-routing OBIS for Amphibalanus amphitrite:   0%|  | 0/1224 [00:00<?, ?record/s]
# Sea-routing OBIS for Amphibalanus amphitrite:   1%| | 12/1224 [00:00<00:10, 111.97
# Sea-routing OBIS for Amphibalanus amphitrite:   2%| | 26/1224 [00:00<00:09, 127.36
# Sea-routing OBIS for Amphibalanus amphitrite:   3%| | 40/1224 [00:00<00:08, 132.27
# Sea-routing OBIS for Amphibalanus amphitrite:   4%| | 55/1224 [00:00<00:08, 137.39
# Sea-routing OBIS for Amphibalanus amphitrite:  83%|▊| 1018/1224 [00:06<00:01, 141.
# Sea-routing OBIS for Amphibalanus amphitrite:  85%|▊| 1037/1224 [00:07<00:01, 153.
# Sea-routing OBIS for Amphibalanus amphitrite:  86%|▊| 1053/1224 [00:07<00:01, 155.
# Sea-routing OBIS for Amphibalanus amphitrite:  87%|▊| 1069/1224 [00:07<00:01, 150.
# Sea-routing OBIS for Amphibalanus amphitrite:  89%|▉| 1085/1224 [00:07<00:00, 148.
# Sea-routing OBIS for Amphibalanus amphitrite:  90%|▉| 1100/1224 [00:07<00:00, 148.
# Sea-routing OBIS for Amphibalanus amphitrite:  91%|▉| 1115/1224 [00:07<00:00, 142.
# Sea-routing OBIS for Amphibalanus amphitrite:  92%|▉| 1131/1224 [00:07<00:00, 145.
# Sea-routing OBIS for Amphibalanus amphitrite:  94%|▉| 1146/1224 [00:07<00:00, 142.
# Sea-routing OBIS for Amphibalanus amphitrite:  95%|▉| 1161/1224 [00:07<00:00, 138.
# Sea-routing OBIS for Amphibalanus amphitrite:  96%|▉| 1175/1224 [00:08<00:00, 138.
# Sea-routing OBIS for Amphibalanus amphitrite:  97%|▉| 1191/1224 [00:08<00:00, 143.
# Sea-routing OBIS for Amphibalanus amphitrite:  99%|▉| 1206/1224 [00:08<00:00, 140.
# Sea-routing OBIS for Amphibalanus amphitrite: 100%|▉| 1221/1224 [00:08<00:00, 141.
#
# WRiMS status for Amphibalanus amphitrite:   0%|       | 0/2 [00:00<?, ?location/s]
# WRiMS status for Amphibalanus amphitrite:  50%|▌| 1/2 [00:01<00:01,  1.79s/locatio
# WRiMS status for Amphibalanus amphitrite: 100%|█| 2/2 [00:03<00:00,  1.93s/locatio
# Total analyses:   6%|█▋                          | 3/50 [01:25<18:30, 23.63s/case]
# Sea-routing OBIS for Amphibalanus improvisus:   0%| | 0/10000 [00:00<?, ?record/s]
# Sea-routing OBIS for Amphibalanus improvisus:   1%| | 101/10000 [00:00<00:09, 1009
# Sea-routing OBIS for Amphibalanus improvisus:   2%| | 213/10000 [00:00<00:09, 1070
# Sea-routing OBIS for Amphibalanus improvisus:   3%| | 341/10000 [00:00<00:08, 1151
# Sea-routing OBIS for Amphibalanus improvisus:   5%| | 457/10000 [00:00<00:08, 1150
# Sea-routing OBIS for Amphibalanus improvisus:   6%| | 572/10000 [00:00<00:08, 1136
# Sea-routing OBIS for Amphibalanus improvisus:   7%| | 686/10000 [00:00<00:08, 1039
# Sea-routing OBIS for Amphibalanus improvisus:   8%| | 814/10000 [00:00<00:08, 1106
# Sea-routing OBIS for Amphibalanus improvisus:   9%| | 926/10000 [00:00<00:08, 1037
# Sea-routing OBIS for Amphibalanus improvisus:  10%| | 1034/10000 [00:00<00:08, 104
# Sea-routing OBIS for Amphibalanus improvisus:  11%| | 1141/10000 [00:01<00:08, 104
# Sea-routing OBIS for Amphibalanus improvisus:  12%| | 1249/10000 [00:01<00:08, 104
# Sea-routing OBIS for Amphibalanus improvisus:  14%|▏| 1381/10000 [00:01<00:07, 112
# Sea-routing OBIS for Amphibalanus improvisus:  15%|▏| 1495/10000 [00:01<00:07, 109
# Sea-routing OBIS for Amphibalanus improvisus:  16%|▏| 1615/10000 [00:01<00:07, 112
# Sea-routing OBIS for Amphibalanus improvisus:  17%|▏| 1728/10000 [00:01<00:08, 992
# Sea-routing OBIS for Amphibalanus improvisus:  18%|▏| 1834/10000 [00:01<00:08, 100
# Sea-routing OBIS for Amphibalanus improvisus:  20%|▏| 1962/10000 [00:01<00:07, 108
# Sea-routing OBIS for Amphibalanus improvisus:  21%|▏| 2074/10000 [00:01<00:07, 109
# Sea-routing OBIS for Amphibalanus improvisus:  22%|▏| 2199/10000 [00:02<00:06, 112
# Sea-routing OBIS for Amphibalanus improvisus:  23%|▏| 2313/10000 [00:02<00:07, 108
# Sea-routing OBIS for Amphibalanus improvisus:  24%|▏| 2431/10000 [00:02<00:06, 111
# Sea-routing OBIS for Amphibalanus improvisus:  25%|▎| 2545/10000 [00:02<00:06, 111
# Sea-routing OBIS for Amphibalanus improvisus:  27%|▎| 2658/10000 [00:02<00:06, 108
# Sea-routing OBIS for Amphibalanus improvisus:  28%|▎| 2767/10000 [00:02<00:06, 107
# Sea-routing OBIS for Amphibalanus improvisus:  29%|▎| 2876/10000 [00:02<00:06, 105
# Sea-routing OBIS for Amphibalanus improvisus:  30%|▎| 2995/10000 [00:02<00:06, 109
# Sea-routing OBIS for Amphibalanus improvisus:  31%|▎| 3105/10000 [00:02<00:06, 108
# Sea-routing OBIS for Amphibalanus improvisus:  32%|▎| 3214/10000 [00:02<00:06, 107
# Sea-routing OBIS for Amphibalanus improvisus:  33%|▎| 3337/10000 [00:03<00:05, 111
# Sea-routing OBIS for Amphibalanus improvisus:  34%|▎| 3450/10000 [00:03<00:05, 111
# Sea-routing OBIS for Amphibalanus improvisus:  36%|▎| 3566/10000 [00:03<00:05, 112
# Sea-routing OBIS for Amphibalanus improvisus:  37%|▎| 3679/10000 [00:03<00:05, 110
# Sea-routing OBIS for Amphibalanus improvisus:  38%|▍| 3790/10000 [00:03<00:05, 104
# Sea-routing OBIS for Amphibalanus improvisus:  39%|▍| 3896/10000 [00:03<00:05, 104
# Sea-routing OBIS for Amphibalanus improvisus:  40%|▍| 4012/10000 [00:03<00:05, 108
# Sea-routing OBIS for Amphibalanus improvisus:  41%|▍| 4148/10000 [00:03<00:05, 116
# Sea-routing OBIS for Amphibalanus improvisus:  43%|▍| 4286/10000 [00:03<00:04, 121
# Sea-routing OBIS for Amphibalanus improvisus:  44%|▍| 4408/10000 [00:04<00:04, 121
# Sea-routing OBIS for Amphibalanus improvisus:  45%|▍| 4530/10000 [00:04<00:04, 115
# Sea-routing OBIS for Amphibalanus improvisus:  47%|▍| 4654/10000 [00:04<00:04, 118
# Sea-routing OBIS for Amphibalanus improvisus:  48%|▍| 4780/10000 [00:04<00:04, 120
# Sea-routing OBIS for Amphibalanus improvisus:  49%|▍| 4901/10000 [00:04<00:04, 111
# Sea-routing OBIS for Amphibalanus improvisus:  50%|▌| 5027/10000 [00:04<00:04, 114
# Sea-routing OBIS for Amphibalanus improvisus:  51%|▌| 5143/10000 [00:04<00:04, 111
# Sea-routing OBIS for Amphibalanus improvisus:  53%|▌| 5272/10000 [00:04<00:04, 116
# Sea-routing OBIS for Amphibalanus improvisus:  54%|▌| 5391/10000 [00:04<00:03, 116
# Sea-routing OBIS for Amphibalanus improvisus:  55%|▌| 5519/10000 [00:04<00:03, 120
# Sea-routing OBIS for Amphibalanus improvisus:  56%|▌| 5640/10000 [00:05<00:03, 118
# Sea-routing OBIS for Amphibalanus improvisus:  58%|▌| 5760/10000 [00:05<00:03, 118
# Sea-routing OBIS for Amphibalanus improvisus:  59%|▌| 5880/10000 [00:05<00:03, 118
# Sea-routing OBIS for Amphibalanus improvisus:  60%|▌| 6007/10000 [00:05<00:03, 120
# Sea-routing OBIS for Amphibalanus improvisus:  61%|▌| 6128/10000 [00:05<00:03, 119
# Sea-routing OBIS for Amphibalanus improvisus:  62%|▌| 6248/10000 [00:05<00:03, 113
# Sea-routing OBIS for Amphibalanus improvisus:  64%|▋| 6363/10000 [00:05<00:03, 109
# Sea-routing OBIS for Amphibalanus improvisus:  65%|▋| 6479/10000 [00:05<00:03, 111
# Sea-routing OBIS for Amphibalanus improvisus:  66%|▋| 6593/10000 [00:05<00:03, 112
# Sea-routing OBIS for Amphibalanus improvisus:  67%|▋| 6706/10000 [00:06<00:02, 111
# Sea-routing OBIS for Amphibalanus improvisus:  68%|▋| 6826/10000 [00:06<00:02, 114
# Sea-routing OBIS for Amphibalanus improvisus:  69%|▋| 6945/10000 [00:06<00:02, 115
# Sea-routing OBIS for Amphibalanus improvisus:  71%|▋| 7066/10000 [00:06<00:02, 116
# Sea-routing OBIS for Amphibalanus improvisus:  72%|▋| 7187/10000 [00:06<00:02, 117
# Sea-routing OBIS for Amphibalanus improvisus:  73%|▋| 7305/10000 [00:06<00:02, 117
# Sea-routing OBIS for Amphibalanus improvisus:  74%|▋| 7426/10000 [00:06<00:02, 118
# Sea-routing OBIS for Amphibalanus improvisus:  75%|▊| 7545/10000 [00:06<00:02, 105
# Sea-routing OBIS for Amphibalanus improvisus:  77%|▊| 7653/10000 [00:06<00:02, 101
# Sea-routing OBIS for Amphibalanus improvisus:  78%|▊| 7779/10000 [00:06<00:02, 106
# Sea-routing OBIS for Amphibalanus improvisus:  79%|▊| 7887/10000 [00:07<00:01, 106
# Sea-routing OBIS for Amphibalanus improvisus:  80%|▊| 7995/10000 [00:07<00:01, 102
# Sea-routing OBIS for Amphibalanus improvisus:  81%|▊| 8126/10000 [00:07<00:01, 110
# Sea-routing OBIS for Amphibalanus improvisus:  82%|▊| 8238/10000 [00:07<00:01, 107
# Sea-routing OBIS for Amphibalanus improvisus:  84%|▊| 8357/10000 [00:07<00:01, 110
# Sea-routing OBIS for Amphibalanus improvisus:  85%|▊| 8476/10000 [00:07<00:01, 112
# Sea-routing OBIS for Amphibalanus improvisus:  86%|▊| 8591/10000 [00:07<00:01, 113
# Sea-routing OBIS for Amphibalanus improvisus:  87%|▊| 8705/10000 [00:07<00:01, 107
# Sea-routing OBIS for Amphibalanus improvisus:  88%|▉| 8830/10000 [00:07<00:01, 111
# Sea-routing OBIS for Amphibalanus improvisus:  90%|▉| 8956/10000 [00:08<00:00, 115
# Sea-routing OBIS for Amphibalanus improvisus:  91%|▉| 9073/10000 [00:08<00:00, 109
# Sea-routing OBIS for Amphibalanus improvisus:  92%|▉| 9184/10000 [00:08<00:00, 109
# Sea-routing OBIS for Amphibalanus improvisus:  93%|▉| 9294/10000 [00:08<00:00, 103
# Sea-routing OBIS for Amphibalanus improvisus:  94%|▉| 9399/10000 [00:08<00:00, 103
# Sea-routing OBIS for Amphibalanus improvisus:  95%|▉| 9508/10000 [00:08<00:00, 105
# Sea-routing OBIS for Amphibalanus improvisus:  96%|▉| 9614/10000 [00:08<00:00, 103
# Sea-routing OBIS for Amphibalanus improvisus:  97%|▉| 9742/10000 [00:08<00:00, 110
# Sea-routing OBIS for Amphibalanus improvisus:  99%|▉| 9853/10000 [00:08<00:00, 108
# Sea-routing OBIS for Amphibalanus improvisus: 100%|▉| 9987/10000 [00:08<00:00, 115
#
# WRiMS status for Amphibalanus improvisus:   0%|       | 0/2 [00:00<?, ?location/s]
# WRiMS status for Amphibalanus improvisus:  50%|▌| 1/2 [00:02<00:02,  2.36s/locatio
# WRiMS status for Amphibalanus improvisus: 100%|█| 2/2 [00:03<00:00,  1.87s/locatio
# Total analyses:   8%|██▏                         | 4/50 [02:02<22:09, 28.90s/case]
# Sea-routing OBIS for Ampithoe valida:   0%|           | 0/531 [00:00<?, ?record/s]
# Sea-routing OBIS for Ampithoe valida:   2%| | 11/531 [00:00<00:05, 103.21record/s]
# Sea-routing OBIS for Ampithoe valida:   5%| | 24/531 [00:00<00:04, 116.73record/s]
# Sea-routing OBIS for Ampithoe valida:   7%| | 37/531 [00:00<00:04, 120.63record/s]
# Sea-routing OBIS for Ampithoe valida:  10%| | 51/531 [00:00<00:03, 126.67record/s]
# Sea-routing OBIS for Ampithoe valida:  12%| | 66/531 [00:00<00:03, 134.04record/s]
# Sea-routing OBIS for Ampithoe valida:  15%|▏| 82/531 [00:00<00:03, 140.87record/s]
# Sea-routing OBIS for Ampithoe valida:  18%|▏| 97/531 [00:00<00:03, 138.04record/s]
# Sea-routing OBIS for Ampithoe valida:  21%|▏| 111/531 [00:00<00:03, 137.87record/s
# Sea-routing OBIS for Ampithoe valida:  24%|▏| 125/531 [00:00<00:03, 134.78record/s
# Sea-routing OBIS for Ampithoe valida:  26%|▎| 139/531 [00:01<00:02, 133.31record/s
# Sea-routing OBIS for Ampithoe valida:  29%|▎| 153/531 [00:01<00:02, 134.72record/s
# Sea-routing OBIS for Ampithoe valida:  32%|▎| 168/531 [00:01<00:02, 137.86record/s
# Sea-routing OBIS for Ampithoe valida:  35%|▎| 184/531 [00:01<00:02, 141.81record/s
# Sea-routing OBIS for Ampithoe valida:  37%|▎| 199/531 [00:01<00:02, 143.32record/s
# Sea-routing OBIS for Ampithoe valida:  40%|▍| 214/531 [00:01<00:02, 144.32record/s
# Sea-routing OBIS for Ampithoe valida:  43%|▍| 229/531 [00:01<00:02, 144.65record/s
# Sea-routing OBIS for Ampithoe valida:  46%|▍| 244/531 [00:01<00:02, 141.81record/s
# Sea-routing OBIS for Ampithoe valida:  49%|▍| 259/531 [00:01<00:01, 141.40record/s
# Sea-routing OBIS for Ampithoe valida:  52%|▌| 274/531 [00:01<00:01, 143.13record/s
# Sea-routing OBIS for Ampithoe valida:  54%|▌| 289/531 [00:02<00:01, 140.56record/s
# Sea-routing OBIS for Ampithoe valida:  57%|▌| 304/531 [00:02<00:01, 139.32record/s
# Sea-routing OBIS for Ampithoe valida:  60%|▌| 319/531 [00:02<00:01, 139.99record/s
# Sea-routing OBIS for Ampithoe valida:  63%|▋| 334/531 [00:02<00:01, 136.88record/s
# Sea-routing OBIS for Ampithoe valida:  66%|▋| 348/531 [00:02<00:01, 134.77record/s
# Sea-routing OBIS for Ampithoe valida:  68%|▋| 363/531 [00:02<00:01, 136.20record/s
# Sea-routing OBIS for Ampithoe valida:  71%|▋| 377/531 [00:02<00:01, 134.43record/s
# Sea-routing OBIS for Ampithoe valida:  74%|▋| 391/531 [00:02<00:01, 134.63record/s
# Sea-routing OBIS for Ampithoe valida:  76%|▊| 405/531 [00:02<00:00, 134.91record/s
# Sea-routing OBIS for Ampithoe valida:  79%|▊| 419/531 [00:03<00:00, 134.43record/s
# Sea-routing OBIS for Ampithoe valida:  82%|▊| 433/531 [00:03<00:00, 131.55record/s
# Sea-routing OBIS for Ampithoe valida:  84%|▊| 447/531 [00:03<00:00, 130.88record/s
# Sea-routing OBIS for Ampithoe valida:  87%|▊| 461/531 [00:03<00:00, 132.20record/s
# Sea-routing OBIS for Ampithoe valida:  89%|▉| 475/531 [00:03<00:00, 132.23record/s
# Sea-routing OBIS for Ampithoe valida:  92%|▉| 489/531 [00:03<00:00, 133.41record/s
# Sea-routing OBIS for Ampithoe valida:  95%|▉| 504/531 [00:03<00:00, 137.62record/s
# Sea-routing OBIS for Ampithoe valida:  98%|▉| 518/531 [00:03<00:00, 138.19record/s
#
# WRiMS status for Ampithoe valida:   0%|               | 0/2 [00:00<?, ?location/s]
# WRiMS status for Ampithoe valida:  50%|███▌   | 1/2 [00:01<00:01,  1.59s/location]
# WRiMS status for Ampithoe valida: 100%|███████| 2/2 [00:04<00:00,  2.62s/location]
# Total analyses:  10%|██▊                         | 5/50 [02:12<16:39, 22.21s/case]
# Sea-routing OBIS for Anguillicola crassus:   0%|       | 0/28 [00:00<?, ?record/s]
#
# WRiMS status for Anguillicola crassus:   0%|          | 0/2 [00:00<?, ?location/s]
# WRiMS status for Anguillicola crassus:  50%|█ | 1/2 [00:01<00:01,  1.30s/location]
# WRiMS status for Anguillicola crassus: 100%|██| 2/2 [00:04<00:00,  2.16s/location]
# Total analyses:  12%|███▎                        | 6/50 [02:16<11:50, 16.15s/case]
# Sea-routing OBIS for Antithamnionella ternifolia:   0%| | 0/354 [00:00<?, ?record/
# Sea-routing OBIS for Antithamnionella ternifolia:  23%|▏| 83/354 [00:00<00:00, 828
# Sea-routing OBIS for Antithamnionella ternifolia:  61%|▌| 217/354 [00:00<00:00, 11
# Sea-routing OBIS for Antithamnionella ternifolia:  96%|▉| 341/354 [00:00<00:00, 11
#
# WRiMS status for Antithamnionella ternifolia:   0%|   | 0/2 [00:00<?, ?location/s]
# WRiMS status for Antithamnionella ternifolia:  50%|▌| 1/2 [00:01<00:01,  1.24s/loc
# WRiMS status for Antithamnionella ternifolia: 100%|█| 2/2 [00:05<00:00,  2.83s/loc
# Total analyses:  14%|███▉                        | 7/50 [02:23<09:27, 13.19s/case]
# Sea-routing OBIS for Aplidium glabrum:   0%|          | 0/345 [00:00<?, ?record/s]
# Sea-routing OBIS for Aplidium glabrum:   8%| | 29/345 [00:00<00:01, 289.91record/s
# Sea-routing OBIS for Aplidium glabrum:  25%|▏| 85/345 [00:00<00:00, 439.13record/s
# Sea-routing OBIS for Aplidium glabrum:  43%|▍| 150/345 [00:00<00:00, 529.38record/
# Sea-routing OBIS for Aplidium glabrum:  59%|▌| 203/345 [00:00<00:00, 494.64record/
# Sea-routing OBIS for Aplidium glabrum:  74%|▋| 257/345 [00:00<00:00, 510.00record/
# Sea-routing OBIS for Aplidium glabrum:  93%|▉| 322/345 [00:00<00:00, 554.85record/
#
# WRiMS status for Aplidium glabrum:   0%|              | 0/2 [00:00<?, ?location/s]
# WRiMS status for Aplidium glabrum:  50%|███   | 1/2 [00:02<00:02,  2.08s/location]
# WRiMS status for Aplidium glabrum: 100%|██████| 2/2 [00:05<00:00,  2.99s/location]
# Total analyses:  16%|████▍                       | 8/50 [02:31<08:04, 11.53s/case]
# Sea-routing OBIS for Aurelia coerulea:   0%|            | 0/8 [00:00<?, ?record/s]
# Sea-routing OBIS for Aurelia coerulea:  88%|███▌| 7/8 [00:00<00:00, 68.36record/s]
#
# WRiMS status for Aurelia coerulea:   0%|              | 0/2 [00:00<?, ?location/s]
# WRiMS status for Aurelia coerulea:  50%|███   | 1/2 [00:01<00:01,  1.73s/location]
# WRiMS status for Aurelia coerulea: 100%|██████| 2/2 [00:08<00:00,  4.43s/location]
# Total analyses:  18%|█████                       | 9/50 [02:40<07:12, 10.54s/case]
# Sea-routing OBIS for Austrominius modestus:   0%|   | 0/10000 [00:00<?, ?record/s]
# Sea-routing OBIS for Austrominius modestus:   1%| | 134/10000 [00:00<00:07, 1337.3
# Sea-routing OBIS for Austrominius modestus:   3%| | 281/10000 [00:00<00:06, 1407.6
# Sea-routing OBIS for Austrominius modestus:   5%| | 453/10000 [00:00<00:06, 1549.2
# Sea-routing OBIS for Austrominius modestus:   6%| | 608/10000 [00:00<00:07, 1265.2
# Sea-routing OBIS for Austrominius modestus:   7%| | 741/10000 [00:00<00:07, 1240.6
# Sea-routing OBIS for Austrominius modestus:   9%| | 877/10000 [00:00<00:07, 1276.5
# Sea-routing OBIS for Austrominius modestus:  10%| | 1027/10000 [00:00<00:06, 1322.
# Sea-routing OBIS for Austrominius modestus:  12%| | 1162/10000 [00:00<00:06, 1290.
# Sea-routing OBIS for Austrominius modestus:  13%|▏| 1293/10000 [00:01<00:07, 1230.
# Sea-routing OBIS for Austrominius modestus:  14%|▏| 1418/10000 [00:01<00:07, 1221.
# Sea-routing OBIS for Austrominius modestus:  15%|▏| 1542/10000 [00:01<00:07, 1190.
# Sea-routing OBIS for Austrominius modestus:  17%|▏| 1683/10000 [00:01<00:06, 1251.
# Sea-routing OBIS for Austrominius modestus:  18%|▏| 1845/10000 [00:01<00:06, 1350.
# Sea-routing OBIS for Austrominius modestus:  20%|▏| 1981/10000 [00:01<00:06, 1312.
# Sea-routing OBIS for Austrominius modestus:  21%|▏| 2132/10000 [00:01<00:05, 1368.
# Sea-routing OBIS for Austrominius modestus:  23%|▏| 2280/10000 [00:01<00:05, 1397.
# Sea-routing OBIS for Austrominius modestus:  24%|▏| 2429/10000 [00:01<00:05, 1423.
# Sea-routing OBIS for Austrominius modestus:  26%|▎| 2572/10000 [00:01<00:05, 1338.
# Sea-routing OBIS for Austrominius modestus:  28%|▎| 2769/10000 [00:02<00:04, 1516.
# Sea-routing OBIS for Austrominius modestus:  29%|▎| 2923/10000 [00:02<00:05, 1402.
# Sea-routing OBIS for Austrominius modestus:  31%|▎| 3067/10000 [00:02<00:05, 1345.
# Sea-routing OBIS for Austrominius modestus:  32%|▎| 3247/10000 [00:02<00:04, 1467.
# Sea-routing OBIS for Austrominius modestus:  34%|▎| 3397/10000 [00:02<00:04, 1356.
# Sea-routing OBIS for Austrominius modestus:  35%|▎| 3544/10000 [00:02<00:04, 1382.
# Sea-routing OBIS for Austrominius modestus:  37%|▎| 3685/10000 [00:02<00:04, 1351.
# Sea-routing OBIS for Austrominius modestus:  38%|▍| 3826/10000 [00:02<00:04, 1366.
# Sea-routing OBIS for Austrominius modestus:  40%|▍| 3964/10000 [00:02<00:04, 1271.
# Sea-routing OBIS for Austrominius modestus:  41%|▍| 4120/10000 [00:03<00:04, 1349.
# Sea-routing OBIS for Austrominius modestus:  43%|▍| 4258/10000 [00:03<00:04, 1310.
# Sea-routing OBIS for Austrominius modestus:  44%|▍| 4415/10000 [00:03<00:04, 1379.
# Sea-routing OBIS for Austrominius modestus:  46%|▍| 4555/10000 [00:03<00:04, 1312.
# Sea-routing OBIS for Austrominius modestus:  47%|▍| 4690/10000 [00:03<00:04, 1304.
# Sea-routing OBIS for Austrominius modestus:  48%|▍| 4822/10000 [00:03<00:03, 1297.
# Sea-routing OBIS for Austrominius modestus:  50%|▍| 4953/10000 [00:03<00:03, 1267.
# Sea-routing OBIS for Austrominius modestus:  51%|▌| 5107/10000 [00:03<00:03, 1343.
# Sea-routing OBIS for Austrominius modestus:  53%|▌| 5273/10000 [00:03<00:03, 1434.
# Sea-routing OBIS for Austrominius modestus:  54%|▌| 5418/10000 [00:04<00:03, 1327.
# Sea-routing OBIS for Austrominius modestus:  56%|▌| 5586/10000 [00:04<00:03, 1422.
# Sea-routing OBIS for Austrominius modestus:  57%|▌| 5731/10000 [00:04<00:03, 1405.
# Sea-routing OBIS for Austrominius modestus:  59%|▌| 5876/10000 [00:04<00:02, 1412.
# Sea-routing OBIS for Austrominius modestus:  60%|▌| 6019/10000 [00:04<00:03, 1301.
# Sea-routing OBIS for Austrominius modestus:  62%|▌| 6176/10000 [00:04<00:02, 1368.
# Sea-routing OBIS for Austrominius modestus:  63%|▋| 6315/10000 [00:04<00:02, 1340.
# Sea-routing OBIS for Austrominius modestus:  65%|▋| 6485/10000 [00:04<00:02, 1439.
# Sea-routing OBIS for Austrominius modestus:  66%|▋| 6649/10000 [00:04<00:02, 1486.
# Sea-routing OBIS for Austrominius modestus:  68%|▋| 6799/10000 [00:05<00:02, 1385.
# Sea-routing OBIS for Austrominius modestus:  69%|▋| 6940/10000 [00:05<00:02, 1322.
# Sea-routing OBIS for Austrominius modestus:  71%|▋| 7074/10000 [00:05<00:02, 1302.
# Sea-routing OBIS for Austrominius modestus:  72%|▋| 7241/10000 [00:05<00:01, 1402.
# Sea-routing OBIS for Austrominius modestus:  74%|▋| 7383/10000 [00:05<00:02, 1213.
# Sea-routing OBIS for Austrominius modestus:  75%|▊| 7510/10000 [00:05<00:02, 1217.
# Sea-routing OBIS for Austrominius modestus:  76%|▊| 7636/10000 [00:05<00:01, 1225.
# Sea-routing OBIS for Austrominius modestus:  78%|▊| 7786/10000 [00:05<00:01, 1271.
# Sea-routing OBIS for Austrominius modestus:  79%|▊| 7916/10000 [00:05<00:01, 1244.
# Sea-routing OBIS for Austrominius modestus:  80%|▊| 8045/10000 [00:06<00:01, 1255.
# Sea-routing OBIS for Austrominius modestus:  82%|▊| 8206/10000 [00:06<00:01, 1354.
# Sea-routing OBIS for Austrominius modestus:  83%|▊| 8345/10000 [00:06<00:01, 1362.
# Sea-routing OBIS for Austrominius modestus:  85%|▊| 8483/10000 [00:06<00:01, 1289.
# Sea-routing OBIS for Austrominius modestus:  86%|▊| 8615/10000 [00:06<00:01, 1296.
# Sea-routing OBIS for Austrominius modestus:  87%|▊| 8746/10000 [00:06<00:01, 1250.
# Sea-routing OBIS for Austrominius modestus:  89%|▉| 8887/10000 [00:06<00:00, 1293.
# Sea-routing OBIS for Austrominius modestus:  90%|▉| 9023/10000 [00:06<00:00, 1312.
# Sea-routing OBIS for Austrominius modestus:  92%|▉| 9155/10000 [00:06<00:00, 1278.
# Sea-routing OBIS for Austrominius modestus:  93%|▉| 9284/10000 [00:07<00:00, 1216.
# Sea-routing OBIS for Austrominius modestus:  94%|▉| 9408/10000 [00:07<00:00, 1194.
# Sea-routing OBIS for Austrominius modestus:  96%|▉| 9557/10000 [00:07<00:00, 1275.
# Sea-routing OBIS for Austrominius modestus:  97%|▉| 9686/10000 [00:07<00:00, 1270.
# Sea-routing OBIS for Austrominius modestus:  98%|▉| 9814/10000 [00:07<00:00, 1178.
# Sea-routing OBIS for Austrominius modestus:  99%|▉| 9934/10000 [00:07<00:00, 1084.
#
# WRiMS status for Austrominius modestus:   0%|         | 0/2 [00:00<?, ?location/s]
# WRiMS status for Austrominius modestus:  50%|▌| 1/2 [00:01<00:01,  1.19s/location]
# WRiMS status for Austrominius modestus: 100%|█| 2/2 [00:02<00:00,  1.25s/location]
# Total analyses:  20%|█████▍                     | 10/50 [03:11<11:19, 16.98s/case]
# Sea-routing OBIS for Baccharis halimifolia:   0%|      | 0/39 [00:00<?, ?record/s]
#
# WRiMS status for Baccharis halimifolia:   0%|         | 0/2 [00:00<?, ?location/s]
# WRiMS status for Baccharis halimifolia:  50%|▌| 1/2 [00:01<00:01,  1.50s/location]
# WRiMS status for Baccharis halimifolia: 100%|█| 2/2 [00:04<00:00,  2.44s/location]
# Total analyses:  22%|█████▉                     | 11/50 [03:16<08:38, 13.29s/case]
# Sea-routing OBIS for Balanus glandula:   0%|         | 0/3761 [00:00<?, ?record/s]
# Sea-routing OBIS for Balanus glandula:   0%| | 14/3761 [00:00<00:27, 138.56record/
# Sea-routing OBIS for Balanus glandula:   1%| | 28/3761 [00:00<00:28, 132.46record/
# Sea-routing OBIS for Balanus glandula:   1%| | 42/3761 [00:00<00:28, 129.21record/
# Sea-routing OBIS for Balanus glandula:   1%| | 55/3761 [00:00<00:29, 126.49record/
# Sea-routing OBIS for Balanus glandula:   2%| | 68/3761 [00:00<00:29, 127.08record/
# Sea-routing OBIS for Balanus glandula:   2%| | 81/3761 [00:00<00:29, 126.85record/
# Sea-routing OBIS for Balanus glandula:   2%| | 94/3761 [00:00<00:28, 127.02record/
# Sea-routing OBIS for Balanus glandula:   3%| | 108/3761 [00:00<00:28, 128.26record
# Sea-routing OBIS for Balanus glandula:   3%| | 121/3761 [00:00<00:28, 127.73record
# Sea-routing OBIS for Balanus glandula:   4%| | 135/3761 [00:01<00:27, 129.88record
# Sea-routing OBIS for Balanus glandula:   4%| | 148/3761 [00:01<00:28, 127.94record
# Sea-routing OBIS for Balanus glandula:   4%| | 162/3761 [00:01<00:27, 130.25record
# Sea-routing OBIS for Balanus glandula:   5%| | 176/3761 [00:01<00:27, 129.24record
# Sea-routing OBIS for Balanus glandula:   5%| | 189/3761 [00:01<00:27, 128.71record
# Sea-routing OBIS for Balanus glandula:   5%| | 204/3761 [00:01<00:26, 133.85record
# Sea-routing OBIS for Balanus glandula:   6%| | 218/3761 [00:01<00:26, 132.02record
# Sea-routing OBIS for Balanus glandula:   6%| | 232/3761 [00:01<00:26, 132.86record
# Sea-routing OBIS for Balanus glandula:   7%| | 246/3761 [00:01<00:26, 134.12record
# Sea-routing OBIS for Balanus glandula:   7%| | 260/3761 [00:01<00:26, 133.24record
# Sea-routing OBIS for Balanus glandula:   7%| | 274/3761 [00:02<00:26, 130.37record
# Sea-routing OBIS for Balanus glandula:   8%| | 288/3761 [00:02<00:26, 130.13record
# Sea-routing OBIS for Balanus glandula:   8%| | 302/3761 [00:02<00:26, 131.88record
# Sea-routing OBIS for Balanus glandula:   8%| | 316/3761 [00:02<00:25, 133.52record
# Sea-routing OBIS for Balanus glandula:   9%| | 330/3761 [00:02<00:26, 130.83record
# Sea-routing OBIS for Balanus glandula:   9%| | 344/3761 [00:02<00:26, 128.66record
# Sea-routing OBIS for Balanus glandula:  10%| | 358/3761 [00:02<00:25, 130.96record
# Sea-routing OBIS for Grandidierella japonica:  45%|▍| 693/1557 [00:04<00:05, 156.5
# Sea-routing OBIS for Grandidierella japonica:  46%|▍| 709/1557 [00:04<00:05, 149.2
# Sea-routing OBIS for Grandidierella japonica:  47%|▍| 725/1557 [00:05<00:05, 143.2
# Sea-routing OBIS for Grandidierella japonica:  48%|▍| 740/1557 [00:05<00:05, 139.5
# Sea-routing OBIS for Grandidierella japonica:  48%|▍| 755/1557 [00:05<00:05, 137.6
# Sea-routing OBIS for Grandidierella japonica:  49%|▍| 769/1557 [00:05<00:05, 138.0
# Sea-routing OBIS for Grandidierella japonica:  50%|▌| 784/1557 [00:05<00:05, 139.2
# Sea-routing OBIS for Grandidierella japonica:  51%|▌| 801/1557 [00:05<00:05, 145.1
# Sea-routing OBIS for Grandidierella japonica:  52%|▌| 816/1557 [00:05<00:05, 146.0
# Sea-routing OBIS for Grandidierella japonica:  53%|▌| 831/1557 [00:05<00:05, 144.8
# Sea-routing OBIS for Grandidierella japonica:  54%|▌| 846/1557 [00:05<00:05, 139.8
# Sea-routing OBIS for Grandidierella japonica:  55%|▌| 861/1557 [00:05<00:05, 137.4
# Sea-routing OBIS for Grandidierella japonica:  57%|▌| 881/1557 [00:06<00:04, 152.2
# Sea-routing OBIS for Grandidierella japonica:  58%|▌| 897/1557 [00:06<00:04, 147.3
# Sea-routing OBIS for Grandidierella japonica:  59%|▌| 912/1557 [00:06<00:04, 146.2
# Sea-routing OBIS for Grandidierella japonica:  60%|▌| 927/1557 [00:06<00:04, 144.1
# Sea-routing OBIS for Grandidierella japonica:  61%|▌| 944/1557 [00:06<00:04, 151.0
# Sea-routing OBIS for Grandidierella japonica:  62%|▌| 960/1557 [00:06<00:04, 147.3
# Sea-routing OBIS for Grandidierella japonica:  63%|▋| 976/1557 [00:06<00:03, 149.0
# Sea-routing OBIS for Grandidierella japonica:  64%|▋| 991/1557 [00:06<00:03, 146.2
# Sea-routing OBIS for Grandidierella japonica:  65%|▋| 1006/1557 [00:06<00:03, 147.
# Sea-routing OBIS for Grandidierella japonica:  66%|▋| 1021/1557 [00:07<00:03, 140.
# Sea-routing OBIS for Grandidierella japonica:  67%|▋| 1036/1557 [00:07<00:03, 137.
# Sea-routing OBIS for Grandidierella japonica:  68%|▋| 1052/1557 [00:07<00:03, 141.
# Sea-routing OBIS for Grandidierella japonica:  69%|▋| 1067/1557 [00:07<00:03, 133.
# Sea-routing OBIS for Grandidierella japonica:  69%|▋| 1082/1557 [00:07<00:03, 136.
# Sea-routing OBIS for Grandidierella japonica:  70%|▋| 1096/1557 [00:07<00:03, 135.
# Sea-routing OBIS for Grandidierella japonica:  71%|▋| 1110/1557 [00:07<00:03, 135.
# Sea-routing OBIS for Grandidierella japonica:  72%|▋| 1124/1557 [00:07<00:03, 132.
# Sea-routing OBIS for Grandidierella japonica:  73%|▋| 1138/1557 [00:07<00:03, 133.
# Sea-routing OBIS for Grandidierella japonica:  74%|▋| 1153/1557 [00:08<00:02, 137.
# Sea-routing OBIS for Grandidierella japonica:  75%|▊| 1168/1557 [00:08<00:02, 139.
# Sea-routing OBIS for Grandidierella japonica:  76%|▊| 1184/1557 [00:08<00:02, 144.
# Sea-routing OBIS for Grandidierella japonica:  77%|▊| 1202/1557 [00:08<00:02, 154.
# Sea-routing OBIS for Grandidierella japonica:  78%|▊| 1218/1557 [00:08<00:02, 153.
# Sea-routing OBIS for Grandidierella japonica:  79%|▊| 1234/1557 [00:08<00:02, 151.
# Sea-routing OBIS for Grandidierella japonica:  80%|▊| 1250/1557 [00:08<00:02, 148.
# Sea-routing OBIS for Grandidierella japonica:  81%|▊| 1265/1557 [00:08<00:02, 145.
# Sea-routing OBIS for Grandidierella japonica:  82%|▊| 1281/1557 [00:08<00:01, 148.
# Sea-routing OBIS for Grandidierella japonica:  83%|▊| 1296/1557 [00:09<00:01, 142.
# Sea-routing OBIS for Grandidierella japonica:  84%|▊| 1311/1557 [00:09<00:01, 135.
# Sea-routing OBIS for Grandidierella japonica:  85%|▊| 1325/1557 [00:09<00:01, 132.
# Sea-routing OBIS for Grandidierella japonica:  86%|▊| 1339/1557 [00:09<00:01, 130.
# Sea-routing OBIS for Grandidierella japonica:  87%|▊| 1355/1557 [00:09<00:01, 135.
# Sea-routing OBIS for Grandidierella japonica:  88%|▉| 1369/1557 [00:09<00:01, 134.
# Sea-routing OBIS for Grandidierella japonica:  89%|▉| 1385/1557 [00:09<00:01, 138.
# Sea-routing OBIS for Grandidierella japonica:  90%|▉| 1401/1557 [00:09<00:01, 142.
# Sea-routing OBIS for Grandidierella japonica:  91%|▉| 1417/1557 [00:09<00:00, 146.
# Sea-routing OBIS for Grandidierella japonica:  92%|▉| 1432/1557 [00:10<00:00, 141.
# Sea-routing OBIS for Grandidierella japonica:  93%|▉| 1447/1557 [00:10<00:00, 141.
# Sea-routing OBIS for Grandidierella japonica:  94%|▉| 1462/1557 [00:10<00:00, 136.
# Sea-routing OBIS for Grandidierella japonica:  95%|▉| 1479/1557 [00:10<00:00, 142.
# Sea-routing OBIS for Grandidierella japonica:  96%|▉| 1494/1557 [00:10<00:00, 142.
# Sea-routing OBIS for Grandidierella japonica:  97%|▉| 1509/1557 [00:10<00:00, 137.
# Sea-routing OBIS for Grandidierella japonica:  98%|▉| 1523/1557 [00:10<00:00, 133.
# Sea-routing OBIS for Grandidierella japonica:  99%|▉| 1537/1557 [00:10<00:00, 134.
# Sea-routing OBIS for Grandidierella japonica: 100%|▉| 1552/1557 [00:10<00:00, 136.
#
# WRiMS status for Grandidierella japonica:   0%|       | 0/2 [00:00<?, ?location/s]
# WRiMS status for Grandidierella japonica:  50%|▌| 1/2 [00:01<00:01,  1.95s/locatio
# WRiMS status for Grandidierella japonica: 100%|█| 2/2 [00:05<00:00,  2.63s/locatio
# Total analyses:  92%|████████████████████████▊  | 46/50 [12:18<00:58, 14.66s/case]
# Sea-routing OBIS for Haliclona xena:   0%|             | 0/24 [00:00<?, ?record/s]
#
# WRiMS status for Haliclona xena:   0%|                | 0/2 [00:00<?, ?location/s]
# WRiMS status for Haloa japonica:   0%|                | 0/2 [00:00<?, ?location/s]
# WRiMS status for Haloa japonica:  50%|████    | 1/2 [00:01<00:01,  1.73s/location]
# WRiMS status for Haloa japonica: 100%|████████| 2/2 [00:03<00:00,  1.67s/location]
# Total analyses:  96%|█████████████████████████▉ | 48/50 [12:29<00:20, 10.19s/case]
# Sea-routing OBIS for Heleobia charruana:   0%|         | 0/48 [00:00<?, ?record/s]
#
# WRiMS status for Heleobia charruana:   0%|            | 0/2 [00:00<?, ?location/s]
# WRiMS status for Heleobia charruana:  50%|██  | 1/2 [00:01<00:01,  1.89s/location]
# WRiMS status for Heleobia charruana: 100%|████| 2/2 [00:04<00:00,  2.13s/location]
# Total analyses:  98%|██████████████████████████▍| 49/50 [12:33<00:08,  8.49s/case]
# Sea-routing OBIS for Hemigrapsus sanguineus:   0%|   | 0/1556 [00:00<?, ?record/s]
# Sea-routing OBIS for Hemigrapsus sanguineus:   2%| | 25/1556 [00:00<00:06, 231.54r
# Sea-routing OBIS for Hemigrapsus sanguineus:   3%| | 49/1556 [00:00<00:07, 212.37r
# Sea-routing OBIS for Hemigrapsus sanguineus:   5%| | 71/1556 [00:00<00:08, 172.45r
# Sea-routing OBIS for Hemigrapsus sanguineus:   6%| | 93/1556 [00:00<00:07, 184.90r
# Sea-routing OBIS for Hemigrapsus sanguineus:   7%| | 116/1556 [00:00<00:07, 194.69
# Sea-routing OBIS for Hemigrapsus sanguineus:   9%| | 138/1556 [00:00<00:07, 199.51
# Sea-routing OBIS for Hemigrapsus sanguineus:  10%| | 159/1556 [00:00<00:07, 186.86
# Sea-routing OBIS for Hemigrapsus sanguineus:  12%| | 181/1556 [00:00<00:07, 194.45
# Sea-routing OBIS for Hemigrapsus sanguineus:  13%|▏| 201/1556 [00:01<00:07, 177.92
# Sea-routing OBIS for Hemigrapsus sanguineus:  14%|▏| 220/1556 [00:01<00:07, 177.31
# Sea-routing OBIS for Hemigrapsus sanguineus:  16%|▏| 242/1556 [00:01<00:06, 188.73
# Sea-routing OBIS for Hemigrapsus sanguineus:  17%|▏| 262/1556 [00:01<00:07, 183.17
# Sea-routing OBIS for Hemigrapsus sanguineus:  18%|▏| 281/1556 [00:01<00:06, 183.94
# Sea-routing OBIS for Hemigrapsus sanguineus:  19%|▏| 301/1556 [00:01<00:06, 184.26
# Sea-routing OBIS for Hemigrapsus sanguineus:  21%|▏| 321/1556 [00:01<00:06, 186.04
# Sea-routing OBIS for Hemigrapsus sanguineus:  22%|▏| 343/1556 [00:01<00:06, 194.05
# Sea-routing OBIS for Hemigrapsus sanguineus:  23%|▏| 363/1556 [00:01<00:06, 183.21
# Sea-routing OBIS for Hemigrapsus sanguineus:  25%|▏| 382/1556 [00:02<00:06, 171.51
# Sea-routing OBIS for Hemigrapsus sanguineus:  26%|▎| 400/1556 [00:02<00:06, 171.90
# Sea-routing OBIS for Hemigrapsus sanguineus:  27%|▎| 418/1556 [00:02<00:06, 173.71
# Sea-routing OBIS for Hemigrapsus sanguineus:  28%|▎| 437/1556 [00:02<00:06, 176.84
# Sea-routing OBIS for Hemigrapsus sanguineus:  68%|▋| 1056/1556 [00:05<00:02, 199.5
# Sea-routing OBIS for Hemigrapsus sanguineus:  69%|▋| 1077/1556 [00:05<00:02, 190.8
# Sea-routing OBIS for Hemigrapsus sanguineus:  71%|▋| 1097/1556 [00:05<00:02, 188.2
# Sea-routing OBIS for Hemigrapsus sanguineus:  72%|▋| 1116/1556 [00:05<00:02, 180.2
# Sea-routing OBIS for Hemigrapsus sanguineus:  73%|▋| 1138/1556 [00:06<00:02, 189.7
# Sea-routing OBIS for Hemigrapsus sanguineus:  74%|▋| 1158/1556 [00:06<00:02, 185.5
# Sea-routing OBIS for Hemigrapsus sanguineus:  76%|▊| 1180/1556 [00:06<00:01, 193.3
# Sea-routing OBIS for Hemigrapsus sanguineus:  77%|▊| 1200/1556 [00:06<00:01, 191.8
# Sea-routing OBIS for Hemigrapsus sanguineus:  78%|▊| 1220/1556 [00:06<00:01, 178.6
# Sea-routing OBIS for Hemigrapsus sanguineus:  80%|▊| 1245/1556 [00:06<00:01, 196.4
# Sea-routing OBIS for Hemigrapsus sanguineus:  81%|▊| 1265/1556 [00:06<00:01, 196.6
# Sea-routing OBIS for Hemigrapsus sanguineus:  83%|▊| 1285/1556 [00:06<00:01, 188.4
# Sea-routing OBIS for Hemigrapsus sanguineus:  84%|▊| 1305/1556 [00:06<00:01, 168.0
# Sea-routing OBIS for Hemigrapsus sanguineus:  85%|▊| 1326/1556 [00:07<00:01, 178.2
# Sea-routing OBIS for Hemigrapsus sanguineus:  86%|▊| 1345/1556 [00:07<00:01, 170.0
# Sea-routing OBIS for Hemigrapsus sanguineus:  88%|▉| 1364/1556 [00:07<00:01, 172.8
# Sea-routing OBIS for Hemigrapsus sanguineus:  89%|▉| 1383/1556 [00:07<00:00, 177.0
# Sea-routing OBIS for Hemigrapsus sanguineus:  90%|▉| 1401/1556 [00:07<00:00, 174.3
# Sea-routing OBIS for Hemigrapsus sanguineus:  91%|▉| 1419/1556 [00:07<00:00, 174.6
# Sea-routing OBIS for Hemigrapsus sanguineus:  93%|▉| 1441/1556 [00:07<00:00, 186.4
# Sea-routing OBIS for Hemigrapsus sanguineus:  94%|▉| 1465/1556 [00:07<00:00, 198.0
# Sea-routing OBIS for Hemigrapsus sanguineus:  96%|▉| 1486/1556 [00:07<00:00, 200.1
# Sea-routing OBIS for Hemigrapsus sanguineus:  97%|▉| 1507/1556 [00:08<00:00, 194.1
# Sea-routing OBIS for Hemigrapsus sanguineus:  98%|▉| 1527/1556 [00:08<00:00, 185.1
# Sea-routing OBIS for Hemigrapsus sanguineus: 100%|▉| 1549/1556 [00:08<00:00, 190.6
#
# WRiMS status for Hemigrapsus sanguineus:   0%|        | 0/2 [00:00<?, ?location/s]
# WRiMS status for Hemigrapsus sanguineus:  50%|▌| 1/2 [00:01<00:01,  1.14s/location
# WRiMS status for Hemigrapsus sanguineus: 100%|█| 2/2 [00:03<00:00,  1.93s/location
# Total analyses: 100%|███████████████████████████| 50/50 [12:47<00:00, 15.36s/case]
# Done. Results written to: analysis_results.tsv
